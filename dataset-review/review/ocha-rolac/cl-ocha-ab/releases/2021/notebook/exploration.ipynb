# %%
import pandas as pd
import geopandas as gpd
import pyarrow as pa
import pyarrow.parquet as pq

base = "../sample"
chile = gpd.read_file(f"{base}/chl_admin3.gpkg")
locode = gpd.read_file(f"{base}/../../../../../uncece/uncece-unlocode/releases/2024/sample/raw_data_uncece_unlocode.gpkg")
locode_cl = locode[locode["country"] == "CL"].copy()
locode_cl["locode"] = locode_cl["country"] + " " + locode_cl["locode"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
#       2 import geopandas as gpd
# ----> 3 import pyarrow as pa
#       4 import pyarrow.parquet as pq
#       6 base = "../sample"
#
# ModuleNotFoundError: No module named 'pyarrow'

# %%
# Spatial join: which locode points fall in which comuna
joined = gpd.sjoin(
    chile,
    locode_cl[["locode", "name", "name_wo_diacritics", "geometry"]],
    how="left",
    predicate="intersects",
)
# Out:
# /var/folders/sb/7n1bm8g546s726d75lp545wm0000gn/T/ipykernel_33371/1829693220.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: GEOGCS["Undefined geographic SRS",DATUM["unknown", ...
# Right CRS: EPSG:4326
#
#   joined = gpd.sjoin(

# %%
def norm(s):
    if pd.isna(s): return ""
    s = str(s).lower().strip()
    for a, b in [("á","a"),("é","e"),("í","i"),("ó","o"),("ú","u"),("ñ","n")]:
        s = s.replace(a, b)
    return s

def name_match_rank(cn, ln, has_locode):
    """0=exact, 1=partial, 2=no match. 999 if no locode."""
    if not has_locode: return 999
    if cn == ln: return 0
    return 1 if (cn in ln or ln in cn) else 2

joined["comuna_norm"] = joined["adm3_name"].apply(norm)
joined["locode_norm"] = joined["name_wo_diacritics"].fillna(joined["name"]).apply(norm)
joined["rank"] = joined.apply(
    lambda r: name_match_rank(r["comuna_norm"], r["locode_norm"], pd.notna(r["locode"])),
    axis=1,
)
joined = joined.sort_values(["adm3_pcode", "rank", "locode"])

# %%
# Spatial match: only keep rank 0 (exact) or 1 (partial); never assign rank 2
valid = joined[joined["rank"] <= 1].drop_duplicates(subset=["adm3_pcode"], keep="first")

mapping = (
    chile[["adm0_pcode", "adm1_pcode", "adm1_name", "adm3_pcode", "adm3_name", "geometry"]]
    .merge(valid[["adm3_pcode", "locode", "name"]], on="adm3_pcode", how="left")
    .rename(columns={
        "adm0_pcode": "country_code", "adm1_pcode": "region_code", "adm1_name": "region_name",
        "adm3_pcode": "comuna_code", "adm3_name": "comuna_name", "name": "locode_name",
    })
)

# Fallback: nearest locode within ~25 km for comunas with no match (only if name matches)
missing = mapping[mapping["locode"].isna()]
if len(missing) > 0:
    used = set(mapping["locode"].dropna())
    avail = locode_cl[~locode_cl["locode"].isin(used)].to_crs("EPSG:4326")
    pts = chile[chile["adm3_pcode"].isin(missing["comuna_code"])].to_crs("EPSG:4326")
    pts = pts.copy()
    pts["centroid"] = pts.geometry.centroid
    pts = pts.set_geometry("centroid")
    fb = gpd.sjoin_nearest(pts, avail[["locode", "name", "geometry"]], how="left", max_distance=0.25, distance_col="dist_deg")
    fb["comuna_norm"] = fb["adm3_name"].apply(norm)
    fb["locode_norm"] = fb["name"].fillna("").apply(norm)
    fb["rank"] = fb.apply(lambda r: name_match_rank(r["comuna_norm"], r["locode_norm"], pd.notna(r["locode"])), axis=1)
    fb = fb[fb["rank"] <= 1].sort_values(["adm3_pcode", "rank", "locode"]).drop_duplicates("adm3_pcode", keep="first")
    fb = fb.dropna(subset=["locode"]).sort_values(["locode", "rank", "dist_deg"]).drop_duplicates("locode", keep="first")
    fill = fb.set_index("adm3_pcode")[["locode", "name"]].rename(columns={"name": "locode_name"})
    mapping = mapping.set_index("comuna_code")
    mapping.loc[fill.index, ["locode", "locode_name"]] = fill
    mapping = mapping.reset_index()

mapping = mapping.sort_values("comuna_code")

# Sanity check
dup = mapping["locode"].notna() & mapping.duplicated(subset=["locode"], keep=False)
print("OK: each locode at most one comuna" if not dup.any() else mapping.loc[dup, ["comuna_name", "locode"]])
mapping
# Out:
# OK: each locode at most one comuna
# /var/folders/sb/7n1bm8g546s726d75lp545wm0000gn/T/ipykernel_33371/788042415.py:20: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   pts["centroid"] = pts.geometry.centroid
# /Users/amandaeames/Documents/gitrepo/geospatial-data/.venv/lib/python3.13/site-packages/geopandas/array.py:411: UserWarning: Geometry is in a geographic CRS. Results from 'sjoin_nearest' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   warnings.warn(
#     comuna_code country_code region_code         region_name    comuna_name  \
# 0       CL01101           CL        CL01  Región de Tarapacá        Iquique
# 1       CL01107           CL        CL01  Región de Tarapacá  Alto Hospicio
# 2       CL01401           CL        CL01  Región de Tarapacá      Tocopilla
# 3       CL01402           CL        CL01  Región de Tarapacá         Camiña
# 4       CL01403           CL        CL01  Región de Tarapacá       Colchane
# ..          ...          ...         ...                 ...            ...
# 340     CL16301           CL        CL16     Región de Ñuble     San Carlos
# 341     CL16302           CL        CL16     Región de Ñuble       Coihueco
# 342     CL16303           CL        CL16     Región de Ñuble         Ñiquén
# 343     CL16304           CL        CL16     Región de Ñuble     San Fabián
# 344     CL16305           CL        CL16     Región de Ñuble    San Nicolás
#
#                                               geometry  locode    locode_name
# 0    MULTIPOLYGON (((-70.13758 -20.19266, -70.13766...  CL IQQ        Iquique
# 1    POLYGON ((-69.89186 -20.06942, -69.89126 -20.0...  CL AHP  Alto Hospicio
# 2    MULTIPOLYGON (((-68.98991 -19.92163, -68.99185...     NaN            NaN
# 3    MULTIPOLYGON (((-69.31816 -19.13586, -69.31819...  CL CMA         Camiña
# 4    POLYGON ((-68.95021 -18.93674, -68.9502 -18.93...  CL CNE       Colchane
# ..                                                 ...     ...            ...
# 340  POLYGON ((-72.22055 -36.20812, -72.22049 -36.2...  CL SCR     San Carlos
# 341  POLYGON ((-71.76365 -36.4805, -71.76478 -36.48...  CL COI       Coihueco
# 342  POLYGON ((-72.09907 -36.13712, -72.09972 -36.1...  CL NQN         Ñiquén
# 343  POLYGON ((-71.09839 -36.36997, -71.09866 -36.3...  CL SFN     San Fabián
# 344  POLYGON ((-72.24538 -36.35148, -72.24773 -36.3...  CL SNI    San Nicolás
#
# [345 rows x 8 columns]

# %%
gpd.GeoDataFrame(mapping, geometry="geometry", crs=chile.crs).to_file(f"{base}/cl_admin_locode.gpkg", driver="GPKG")

# %%
# Export to GeoParquet for S3 upload
# GeoParquet supports byte-range reads from S3 — much faster than GeoPackage (60.7 MB full download)
output = gpd.GeoDataFrame(mapping, geometry="geometry", crs=chile.crs).to_crs("EPSG:4326")
output.to_parquet(f"{base}/raw_data_cl_ocha_ab.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Export to GeoParquet for S3 upload
#       2 # GeoParquet supports byte-range reads from S3 — much faster than GeoPackage (60.7 MB full download)
#       3 output = gpd.GeoDataFrame(mapping, geometry="geometry", crs=chile.crs).to_crs("EPSG:4326")
# ----> 4 output.to_parquet(f"{base}/raw_data_cl_ocha_ab.parquet")
#
# File ~/Documents/gitrepo/geospatial-data/.venv/lib/python3.13/site-packages/geopandas/geodataframe.py:1464, in GeoDataFrame.to_parquet(self, path, index, compression, geometry_encoding, write_covering_bbox, schema_version, **kwargs)
#    1457     raise ValueError(
#    1458         "GeoPandas only supports using pyarrow as the engine for "
#    1459         f"to_parquet: {engine!r} passed instead."
#    1460     )
#    1462 from geopandas.io.arrow import _to_parquet
# -> 1464 _to_parquet(
#    1465     self,
#    1466     path,
#    1467     compression=compression,
#    1468     geometry_encoding=geometry_encoding,
#    1469     index=index,
#    1470     schema_version=schema_version,
#    1471     write_covering_bbox=write_covering_bbox,
#    1472     **kwargs,
#    1473 )
#
# File ~/Documents/gitrepo/geospatial-data/.venv/lib/python3.13/site-packages/geopandas/io/arrow.py:435, in _to_parquet(df, path, index, compression, geometry_encoding, schema_version, write_covering_bbox, **kwargs)
#     385 def _to_parquet(
#     386     df,
#     387     path,
#    (...)    393     **kwargs,
#     394 ):
#     395     """
#     396     Write a GeoDataFrame to the Parquet format.
#     397
#    (...)    433         Additional keyword arguments passed to pyarrow.parquet.write_table().
#     434     """
# --> 435     parquet = import_optional_dependency(
#     436         "pyarrow.parquet", extra="pyarrow is required for Parquet support."
#     437     )
#     439     path = _expand_user(path)
#     440     table = _geopandas_to_arrow(
#     441         df,
#     442         index=index,
#    (...)    445         write_covering_bbox=write_covering_bbox,
#     446     )
#
# File ~/Documents/gitrepo/geospatial-data/.venv/lib/python3.13/site-packages/geopandas/_compat.py:62, in import_optional_dependency(name, extra)
#      59     module = importlib.import_module(name)
#      61 except ImportError:
# ---> 62     raise ImportError(msg) from None
#      64 return module
#
# ImportError: Missing optional dependency 'pyarrow.parquet'. pyarrow is required for Parquet support.  "
#         "Use pip or conda to install pyarrow.parquet.
